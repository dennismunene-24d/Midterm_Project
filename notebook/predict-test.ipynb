# %%
import requests

# %%
url = "http://localhost:9696/predict"

# %%
customer = {
    "age": 45,
    "sex": "male",
    "region": "northwest",
    "urban_rural": "urban",
    "income": 75000.0,
    "education": "bachelor",
    "marital_status": "married",
    "employment_status": "employed",
    "household_size": 3,
    "dependents": 1,
    "bmi": 27.5,
    "smoker": "no",
    "alcohol_freq": "never",
    "visits_last_year": 2,
    "hospitalizations_last_3yrs": 0,
    "days_hospitalized_last_3yrs": 0,
    "medication_count": 1,
    "systolic_bp": 120.0,
    "diastolic_bp": 80.0,
    "ldl": 110.0,
    "hba1c": 5.4,
    "plan_type": "HMO",
    "network_tier": "Silver",
    "deductible": 500,
    "copay": 25,
    "policy_term_years": 3,
    "policy_changes_last_2yrs": 0,
    "provider_quality": 4.5,
    "risk_score": 0.2,
    "annual_premium": 5000.0,
    "claims_count": 2,
    "avg_claim_amount": 300.0,
    "total_claims_paid": 600.0,
    "chronic_count": 0,
    "hypertension": 0,
    "proc_imaging_count": 0,
    "proc_surgery_count": 0,
    "proc_physio_count": 0,
    "proc_consult_count": 1,
    "proc_lab_count": 1,
    "is_high_risk": 0,
    "had_major_procedure": 0
}

# %%
response = requests.post(url, json=customer)

# %%
print(response.status_code)
print(response.json())
# Out:
# 200
# {'message': 'Predicted annual medical cost for 1 customer(s)', 'predictions': [48289.69]}

# %%
customers = [


    {
        "age": 45,
        "sex": "male",
        "region": "northwest",
        "urban_rural": "urban",
        "income": 75000.0,
        "education": "bachelor",
        "marital_status": "married",
        "employment_status": "employed",
        "household_size": 3,
        "dependents": 1,
        "bmi": 27.5,
        "smoker": "no",
        "alcohol_freq": "never",
        "visits_last_year": 2,
        "hospitalizations_last_3yrs": 0,
        "days_hospitalized_last_3yrs": 0,
        "medication_count": 1,
        "systolic_bp": 120.0,
        "diastolic_bp": 80.0,
        "ldl": 110.0,
        "hba1c": 5.4,
        "plan_type": "HMO",
        "network_tier": "Silver",
        "deductible": 500,
        "copay": 25,
        "policy_term_years": 3,
        "policy_changes_last_2yrs": 0,
        "provider_quality": 4.5,
        "risk_score": 0.2,
        "annual_premium": 5000.0,
        "claims_count": 2,
        "avg_claim_amount": 300.0,
        "total_claims_paid": 600.0,
        "chronic_count": 0,
        "hypertension": 0,
        "proc_imaging_count": 0,
        "proc_surgery_count": 0,
        "proc_physio_count": 0,
        "proc_consult_count": 1,
        "proc_lab_count": 1,
        "is_high_risk": 0,
        "had_major_procedure": 0
    },

   
    {
        "age": 62,
        "sex": "female",
        "region": "southeast",
        "urban_rural": "rural",
        "income": 54000.0,
        "education": "high_school",
        "marital_status": "widowed",
        "employment_status": "retired",
        "household_size": 1,
        "dependents": 0,
        "bmi": 31.4,
        "smoker": "yes",
        "alcohol_freq": "rarely",
        "visits_last_year": 6,
        "hospitalizations_last_3yrs": 2,
        "days_hospitalized_last_3yrs": 10,
        "medication_count": 5,
        "systolic_bp": 138.0,
        "diastolic_bp": 88.0,
        "ldl": 160.0,
        "hba1c": 6.8,
        "plan_type": "PPO",
        "network_tier": "Gold",
        "deductible": 1200,
        "copay": 35,
        "policy_term_years": 1,
        "policy_changes_last_2yrs": 1,
        "provider_quality": 4.1,
        "risk_score": 1.1,
        "annual_premium": 8200.0,
        "claims_count": 9,
        "avg_claim_amount": 850.0,
        "total_claims_paid": 7650.0,
        "chronic_count": 3,
        "hypertension": 1,
        "proc_imaging_count": 2,
        "proc_surgery_count": 1,
        "proc_physio_count": 3,
        "proc_consult_count": 4,
        "proc_lab_count": 3,
        "is_high_risk": 1,
        "had_major_procedure": 1
    },

  
    {
        "age": 29,
        "sex": "male",
        "region": "southwest",
        "urban_rural": "urban",
        "income": 52000.0,
        "education": "college",
        "marital_status": "single",
        "employment_status": "employed",
        "household_size": 2,
        "dependents": 0,
        "bmi": 23.8,
        "smoker": "no",
        "alcohol_freq": "moderate",
        "visits_last_year": 1,
        "hospitalizations_last_3yrs": 0,
        "days_hospitalized_last_3yrs": 0,
        "medication_count": 0,
        "systolic_bp": 118.0,
        "diastolic_bp": 76.0,
        "ldl": 95.0,
        "hba1c": 5.1,
        "plan_type": "EPO",
        "network_tier": "Bronze",
        "deductible": 1800,
        "copay": 40,
        "policy_term_years": 1,
        "policy_changes_last_2yrs": 0,
        "provider_quality": 3.8,
        "risk_score": 0.15,
        "annual_premium": 3600.0,
        "claims_count": 1,
        "avg_claim_amount": 120.0,
        "total_claims_paid": 120.0,
        "chronic_count": 0,
        "hypertension": 0,
        "proc_imaging_count": 0,
        "proc_surgery_count": 0,
        "proc_physio_count": 0,
        "proc_consult_count": 1,
        "proc_lab_count": 1,
        "is_high_risk": 0,
        "had_major_procedure": 0
    },

    
    {
        "age": 51,
        "sex": "female",
        "region": "northeast",
        "urban_rural": "urban",
        "income": 91000.0,
        "education": "master",
        "marital_status": "married",
        "employment_status": "employed",
        "household_size": 4,
        "dependents": 2,
        "bmi": 26.9,
        "smoker": "no",
        "alcohol_freq": "weekly",
        "visits_last_year": 4,
        "hospitalizations_last_3yrs": 1,
        "days_hospitalized_last_3yrs": 2,
        "medication_count": 2,
        "systolic_bp": 124.0,
        "diastolic_bp": 82.0,
        "ldl": 130.0,
        "hba1c": 5.6,
        "plan_type": "HMO",
        "network_tier": "Platinum",
        "deductible": 300,
        "copay": 20,
        "policy_term_years": 2,
        "policy_changes_last_2yrs": 0,
        "provider_quality": 4.8,
        "risk_score": 0.35,
        "annual_premium": 7200.0,
        "claims_count": 3,
        "avg_claim_amount": 450.0,
        "total_claims_paid": 1350.0,
        "chronic_count": 1,
        "hypertension": 1,
        "proc_imaging_count": 1,
        "proc_surgery_count": 0,
        "proc_physio_count": 1,
        "proc_consult_count": 2,
        "proc_lab_count": 2,
        "is_high_risk": 0,
        "had_major_procedure": 0
    },


    {
        "age": 37,
        "sex": "male",
        "region": "midwest",
        "urban_rural": "rural",
        "income": 45000.0,
        "education": "associate",
        "marital_status": "divorced",
        "employment_status": "self_employed",
        "household_size": 1,
        "dependents": 0,
        "bmi": 29.6,
        "smoker": "yes",
        "alcohol_freq": "moderate",
        "visits_last_year": 5,
        "hospitalizations_last_3yrs": 1,
        "days_hospitalized_last_3yrs": 3,
        "medication_count": 1,
        "systolic_bp": 132.0,
        "diastolic_bp": 86.0,
        "ldl": 142.0,
        "hba1c": 5.9,
        "plan_type": "POS",
        "network_tier": "Silver",
        "deductible": 900,
        "copay": 30,
        "policy_term_years": 2,
        "policy_changes_last_2yrs": 1,
        "provider_quality": 4.0,
        "risk_score": 0.55,
        "annual_premium": 4800.0,
        "claims_count": 4,
        "avg_claim_amount": 220.0,
        "total_claims_paid": 880.0,
        "chronic_count": 1,
        "hypertension": 1,
        "proc_imaging_count": 0,
        "proc_surgery_count": 0,
        "proc_physio_count": 2,
        "proc_consult_count": 2,
        "proc_lab_count": 2,
        "is_high_risk": 0,
        "had_major_procedure": 0
    }

]

# %%
response = requests.post(url, json=customers)

print(response.json())
# Out:
# {'message': 'Predicted annual medical cost for 5 customer(s)', 'predictions': [48289.69, 47176.93, 38468.13, 47176.93, 48289.69]}
